# %% [markdown]
# <a href="https://colab.research.google.com/github/rhiats/Redfin-T-Test/blob/main/Redfin_T_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Two-Tail Test Redfin Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# **Read Data**

# %%
df=pd.read_excel("/content/drive/MyDrive/Data Analytics/ImplementingScientificDecisionMaking/redfin.xlsx")

# %%
df.head()
# Out:
#    PRICE Brooklyn  PRICE Queens
# 0       1950000.0        519000
# 1        639000.0        779000
# 2       1050000.0        899000
# 3        475000.0        229000
# 4        525000.0        325000

# %% [markdown]
# **Remove Nans**

# %%
df_clean = df.dropna()

# %%
df_clean.shape
# Out:
# (177, 2)

# %% [markdown]
# **Random Sample**

# %%
sample_df = df_clean.sample(n=100)

# %%
sample_df.head()
# Out:
#      PRICE Brooklyn  PRICE Queens
# 160       1495000.0        675000
# 154        995000.0       1788000
# 80        1899000.0       1698000
# 22         580000.0       1249000
# 78         259000.0        739000

# %%
sample_df.shape
# Out:
# (100, 2)

# %%
sample_df.to_csv("/content/drive/MyDrive/Data Analytics/ImplementingScientificDecisionMaking/sample.csv", index=False)

# %%
sample_df = pd.read_csv("/content/drive/MyDrive/Data Analytics/ImplementingScientificDecisionMaking/sample_dataset.csv")

# %%
sample_df.tail(3)
# Out:
#               Unnamed: 0  PRICE Brooklyn  PRICE Queens  Unnamed: 3
# 100              Average    1.053593e+06  8.774244e+05         NaN
# 101             Variance    4.931180e+11  2.474770e+11         NaN
# 102  T-Statistic P-Value             NaN           NaN    0.042116

# %%
sample_df = sample_df.iloc[:-3, 1:3]

# %%
sample_df.tail(3)
# Out:
#     PRICE Brooklyn  PRICE Queens
# 97        699000.0      310000.0
# 98        425000.0     1695000.0
# 99        639000.0      779000.0

# %% [markdown]
# **Average of Each Column**

# %%
mean_values = sample_df.mean()
print(mean_values)
# Out:
# PRICE Brooklyn    1053592.74
# PRICE Queens       877424.37
# dtype: float64

# %%
mean_values_population = df.mean()
print(mean_values_population)
# Out:
# PRICE Brooklyn    1.103044e+06
# PRICE Queens      9.435133e+05
# dtype: float64

# %% [markdown]
# **Variance of Each Column**

# %%
variance_values = sample_df.var()
print(variance_values)
# Out:
# PRICE Brooklyn    4.931177e+11
# PRICE Queens      2.474767e+11
# dtype: float64

# %% [markdown]
# **Welch's T-Test**

# %%
queens = sample_df["PRICE Queens"].to_numpy()
brooklyn = sample_df["PRICE Brooklyn"].to_numpy()

# %%
t_stat, p_value = stats.ttest_ind(queens, brooklyn, equal_var=False)

# %%
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")
# Out:
# T-Statistic: -2.0471
# P-Value: 0.0421
